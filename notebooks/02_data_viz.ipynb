# %% [markdown]
# # 0.0 - Imports

# %% [markdown]
# ## 0.1 - Importa as bibliotecas

# %%
import os
import pandas as pd

from dotenv import load_dotenv
from sqlalchemy import create_engine, text

# %% [markdown]
# ## 0.2 - Carrega as credenciais do .env

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## 0.3 - Conexão utilizando o .env

# %%
user = os.getenv('DB_USER')
password = os.getenv('DB_PASS')
host = os.getenv('DB_HOST')
dataset = os.getenv('DB_NAME')

url = create_engine(f"mysql+pymysql://{user}:{password}@{host}/{dataset}")

# %% [markdown]
# ## 0.4 - Teste de Conexão

# %%
with url.connect() as conn:
    result = conn.execute(text("SELECT VERSION();"))
    print(result.fetchone())
# Out:
# ('8.0.31-google',)

# %% [markdown]
# # 1.0 - Execução das consultas

# %%
#Transforma as query em texto para pandas
query_story_cad = text("SELECT STORE_CODE, STORE_NAME, START_DATE, END_DATE, BUSINESS_NAME, BUSINESS_CODE FROM data_store_cad")
query_store_sales = text("SELECT STORE_CODE, DATE, SALES_VALUE, SALES_QTY FROM data_store_sales WHERE DATE BETWEEN '2019-01-01' AND '2019-12-31'")

# %%
#Carrega no pandas as duas tabelas
df_raw_cad = pd.read_sql_query(query_story_cad, con=engine)
df_raw_sales = pd.read_sql_query (query_store_sales, con=engine)

# %%
#Verificação dos tipos do DataFrame
print(df_raw_cad.dtypes)
print(df_raw_sales.dtypes)
# Out:
# STORE_CODE       int64
# STORE_NAME         str
# START_DATE         str
# END_DATE           str
# BUSINESS_NAME      str
# BUSINESS_CODE    int64
# dtype: object
# STORE_CODE       int64
# DATE            object
# SALES_VALUE    float64
# SALES_QTY        int64
# dtype: object

# %%
print(df_raw_cad.head(5))
print(df_raw_sales.head(5))
# Out:
#    STORE_CODE STORE_NAME  START_DATE END_DATE BUSINESS_NAME  BUSINESS_CODE
# 0           1  Sao Paulo  2006-10-01                 Varejo              1
# 1           2    Chicago  2007-10-01                 Varejo              1
# 2           3       Roma  2008-10-01                 Varejo              1
# 3           4      Tokio  2009-10-01                 Varejo              1
# 4           5      Paris  2019-01-01            Proximidade              2
#    STORE_CODE        DATE  SALES_VALUE  SALES_QTY
# 0           1  2019-01-01    196623.22      12838
# 1          10  2019-01-01    126795.44       4933
# 2          11  2019-01-01    223937.00       7724
# 3          12  2019-01-01    200251.80       7043
# 4          13  2019-01-01    196623.22      12838

# %% [markdown]
# # 2.0 - Joins dos datasets

# %%
#INNER JOIN DAS DUAS TABELAS
df1 = pd.merge(df_raw_cad, df_raw_sales, on='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 2
#       1 #INNER JOIN DAS DUAS TABELAS
# ----> 2 df1 = pd.merge(df_raw_cad, df_raw_sales, on='inner')
#
# File ~/.pyenv/versions/3.11.0/envs/data-challenge/lib/python3.11/site-packages/pandas/core/reshape/merge.py:385, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     371     return _cross_merge(
#     372         left_df,
#     373         right_df,
#    (...)    382         validate=validate,
#     383     )
#     384 else:
# --> 385     op = _MergeOperation(
#     386         left_df,
#     387         right_df,
#     388         how=how,
#     389         on=on,
#     390         left_on=left_on,
#     391         right_on=right_on,
#     392         left_index=left_index,
#     393         right_index=right_index,
#     394         sort=sort,
#     395         suffixes=suffixes,
#     396         indicator=indicator,
#     397         validate=validate,
#     398     )
#     399     return op.get_result()
#
# File ~/.pyenv/versions/3.11.0/envs/data-challenge/lib/python3.11/site-packages/pandas/core/reshape/merge.py:1018, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#    1008     raise MergeError(msg)
#    1010 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#    1012 (
#    1013     self.left_join_keys,
#    1014     self.right_join_keys,
#    1015     self.join_names,
#    1016     left_drop,
#    1017     right_drop,
# -> 1018 ) = self._get_merge_keys()
#    1020 if left_drop:
#    1021     self.left = self.left._drop_labels_or_levels(left_drop)
#
# File ~/.pyenv/versions/3.11.0/envs/data-challenge/lib/python3.11/site-packages/pandas/core/reshape/merge.py:1620, in _MergeOperation._get_merge_keys(self)
#    1618 rk = cast(Hashable, rk)
#    1619 if rk is not None:
# -> 1620     right_keys.append(right._get_label_or_level_values(rk))
#    1621 else:
#    1622     # work-around for merge_asof(right_index=True)
#    1623     right_keys.append(right.index._values)
#
# File ~/.pyenv/versions/3.11.0/envs/data-challenge/lib/python3.11/site-packages/pandas/core/generic.py:1776, in NDFrame._get_label_or_level_values(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
#    1773         elif self._is_level_reference(key, axis=axis):
#    1774             values = self.axes[axis].get_level_values(key)._values
#    1775         else:
# -> 1776             raise KeyError(key)
#    1777
#    1778         # Check for duplicates
#    1779         if values.ndim > 1:
#
# KeyError: 'inner'

# %% [markdown]
# # 3.0 - Calculo do Ticket Médio

# %% [markdown]
# # 4.0 - Executa tabela final - Output em DataFrame (Pandas)
