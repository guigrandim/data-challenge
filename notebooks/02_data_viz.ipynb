# %% [markdown]
# # 0.0 - Imports

# %% [markdown]
# ## 0.1 - Importa as bibliotecas

# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine, text

# %% [markdown]
# ## 0.2 - Carrega as credenciais do .env

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## 0.3 - Conexão utilizando o .env

# %%
user = os.getenv('DB_USER')
password = os.getenv('DB_PASS')
host = os.getenv('DB_HOST')
dataset = os.getenv('DB_NAME')

engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}/{dataset}")

# %% [markdown]
# ## 0.4 - Teste de Conexão

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT VERSION();"))
    print(result.fetchone())
# Out:
# ('8.0.31-google',)

# %% [markdown]
# # 1.0 - Execução das consultas

# %% [markdown]
# # 2.0 - Joins dos datasets

# %% [markdown]
# # 3.0 - Calculo do Ticket Médio

# %% [markdown]
# # 4.0 - Executa tabela final - Output em DataFrame (Pandas)
